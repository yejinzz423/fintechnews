# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %% [markdown]
# # 텍스트 전처리

# %%
df = pd.read_csv("./fintech_news.csv")
df
# Out:
#                                                    뉴스제목  \
# 0              FIU, 은행·증권·보험 등 전 금융사와 초국경 범죄 거래 유형 분석한다
# 1             금감원, 금융보안원 가입 GA에 운영실태평가 가점…'보안 역량' 끌어올린다
# 2                회계법인 감사보수 ‘뚝' 떨어지자…금감원 "보수 경쟁보다 품질 우선"
# 3                  금감원장, 키움증권 찾아 '모범사례' 당부…발행어음 투자 주의점은
# 4                  토스뱅크, 금융권 첫 '신분증 진위확인 소프트웨어' 부수업무 신고
# ...                                                 ...
# 9238                     인도네시아, 브릭스 가입…"중국에 한 발 더 가까워져"
# 9239  [CES 2025] 젠슨 황, 로봇 개발 플랫폼 공개…"로봇의 챗GPT 모멘트 온다...
# 9240                 "연준, 확고한 동결 신호 보내"…올해 금리 인하 1회 가능성
# 9241      “인수 포기 못 해” vs “지금 못 팔아”…US스틸 매각 놓고 美·日 갈등 확산
# 9242                       트럼프 복귀에...저커버그, 페북 '팩트체킹' 폐지
#
#                                                    원문링크  \
# 0     https://n.news.naver.com/mnews/article/277/000...
# 1     https://n.news.naver.com/mnews/article/030/000...
# 2     https://n.news.naver.com/mnews/article/648/000...
# 3     https://n.news.naver.com/mnews/article/119/000...
# 4     https://n.news.naver.com/mnews/article/629/000...
# ...                                                 ...
# 9238  https://n.news.naver.com/mnews/article/001/001...
# 9239  https://n.news.naver.com/mnews/article/001/001...
# 9240  https://n.news.naver.com/mnews/article/123/000...
# 9241  https://n.news.naver.com/mnews/article/081/000...
# 9242  https://n.news.naver.com/mnews/article/277/000...
#
#                                                      본문
# 0     이형주 '자금세탁방지 유관기관협의회' 개최앞으로 금융정보분석원(FIU)은 은행, 저...
# 1     이미지=게티이미지뱅크금융감독원이 금융보안원에 가입한 보험대리점(GA)에 대해 내부통...
# 2     감사 부문 전년대비 증가폭 둔화·비감사 부문은 확대회계법인이 외부감사를 통해 받는 ...
# 3     정부 정책 따라 발행어음 사업자 증가경쟁 심화되면 '부실' 우려 커질 수도"리스크 ...
# 4     인공지능(AI) 기반 신분증 진위확인 기술 제공토스뱅크가 금융권 최초로 '신분증 진...
# ...                                                 ...
# 9238  수출시장 확대·달러 의존도 낮추는 데 도움…反서방집단 합류 해석 우려중국 인도네시아...
# 9239  젠슨 황 8년만에 기조연설…로봇·자율주행 등 물리적 AI 개발 '코스모스' 공개日 ...
# 9240  ◆…미 연방준비제도(Fed)가 당분간 금리를 동결하고 올해 금리 인하를 단 한번 단...
# 9241  일본제철, 바이든 불허 불복 소송하시모토 회장 “美에 항전할 것”트럼프 “관세로 더...
# 9242  페이스북과 인스타그램 등을 운영하는 메타플랫폼의 마크 저커버그 최고경영자(CEO)가...
#
# [9243 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['뉴스제목', '원문링크', '본문'], dtype='object')

# %%
df = df[['뉴스제목', '본문']].copy()
df
# Out:
#                                                    뉴스제목  \
# 0              FIU, 은행·증권·보험 등 전 금융사와 초국경 범죄 거래 유형 분석한다
# 1             금감원, 금융보안원 가입 GA에 운영실태평가 가점…'보안 역량' 끌어올린다
# 2                회계법인 감사보수 ‘뚝' 떨어지자…금감원 "보수 경쟁보다 품질 우선"
# 3                  금감원장, 키움증권 찾아 '모범사례' 당부…발행어음 투자 주의점은
# 4                  토스뱅크, 금융권 첫 '신분증 진위확인 소프트웨어' 부수업무 신고
# ...                                                 ...
# 9238                     인도네시아, 브릭스 가입…"중국에 한 발 더 가까워져"
# 9239  [CES 2025] 젠슨 황, 로봇 개발 플랫폼 공개…"로봇의 챗GPT 모멘트 온다...
# 9240                 "연준, 확고한 동결 신호 보내"…올해 금리 인하 1회 가능성
# 9241      “인수 포기 못 해” vs “지금 못 팔아”…US스틸 매각 놓고 美·日 갈등 확산
# 9242                       트럼프 복귀에...저커버그, 페북 '팩트체킹' 폐지
#
#                                                      본문
# 0     이형주 '자금세탁방지 유관기관협의회' 개최앞으로 금융정보분석원(FIU)은 은행, 저...
# 1     이미지=게티이미지뱅크금융감독원이 금융보안원에 가입한 보험대리점(GA)에 대해 내부통...
# 2     감사 부문 전년대비 증가폭 둔화·비감사 부문은 확대회계법인이 외부감사를 통해 받는 ...
# 3     정부 정책 따라 발행어음 사업자 증가경쟁 심화되면 '부실' 우려 커질 수도"리스크 ...
# 4     인공지능(AI) 기반 신분증 진위확인 기술 제공토스뱅크가 금융권 최초로 '신분증 진...
# ...                                                 ...
# 9238  수출시장 확대·달러 의존도 낮추는 데 도움…反서방집단 합류 해석 우려중국 인도네시아...
# 9239  젠슨 황 8년만에 기조연설…로봇·자율주행 등 물리적 AI 개발 '코스모스' 공개日 ...
# 9240  ◆…미 연방준비제도(Fed)가 당분간 금리를 동결하고 올해 금리 인하를 단 한번 단...
# 9241  일본제철, 바이든 불허 불복 소송하시모토 회장 “美에 항전할 것”트럼프 “관세로 더...
# 9242  페이스북과 인스타그램 등을 운영하는 메타플랫폼의 마크 저커버그 최고경영자(CEO)가...
#
# [9243 rows x 2 columns]

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from konlpy) (1.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from konlpy) (6.0.2)
# Requirement already satisfied: numpy>=1.6 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from konlpy) (2.3.5)
# Requirement already satisfied: packaging in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from JPype1>=0.7.0->konlpy) (25.0)

# %%
import re
from konlpy.tag import Mecab
mecab = Mecab()

# %%
def text_clean(x):
    # 한글, 영문대소문자, 숫자만 남기고 모두 제거
    cleaned = re.sub(r'[^가-힣a-zA-Z0-9]', " ", x)
    cleaned = cleaned.replace("  ", " ").replace("  ", " ").strip()
    return cleaned

# %%
def tokenizer(text):
    tokens = mecab.morphs(text)
    return tokens

# %%
df.dropna()
# Out:
#                                                    뉴스제목  \
# 0              FIU, 은행·증권·보험 등 전 금융사와 초국경 범죄 거래 유형 분석한다
# 1             금감원, 금융보안원 가입 GA에 운영실태평가 가점…'보안 역량' 끌어올린다
# 2                회계법인 감사보수 ‘뚝' 떨어지자…금감원 "보수 경쟁보다 품질 우선"
# 3                  금감원장, 키움증권 찾아 '모범사례' 당부…발행어음 투자 주의점은
# 4                  토스뱅크, 금융권 첫 '신분증 진위확인 소프트웨어' 부수업무 신고
# ...                                                 ...
# 9238                     인도네시아, 브릭스 가입…"중국에 한 발 더 가까워져"
# 9239  [CES 2025] 젠슨 황, 로봇 개발 플랫폼 공개…"로봇의 챗GPT 모멘트 온다...
# 9240                 "연준, 확고한 동결 신호 보내"…올해 금리 인하 1회 가능성
# 9241      “인수 포기 못 해” vs “지금 못 팔아”…US스틸 매각 놓고 美·日 갈등 확산
# 9242                       트럼프 복귀에...저커버그, 페북 '팩트체킹' 폐지
#
#                                                      본문
# 0     이형주 '자금세탁방지 유관기관협의회' 개최앞으로 금융정보분석원(FIU)은 은행, 저...
# 1     이미지=게티이미지뱅크금융감독원이 금융보안원에 가입한 보험대리점(GA)에 대해 내부통...
# 2     감사 부문 전년대비 증가폭 둔화·비감사 부문은 확대회계법인이 외부감사를 통해 받는 ...
# 3     정부 정책 따라 발행어음 사업자 증가경쟁 심화되면 '부실' 우려 커질 수도"리스크 ...
# 4     인공지능(AI) 기반 신분증 진위확인 기술 제공토스뱅크가 금융권 최초로 '신분증 진...
# ...                                                 ...
# 9238  수출시장 확대·달러 의존도 낮추는 데 도움…反서방집단 합류 해석 우려중국 인도네시아...
# 9239  젠슨 황 8년만에 기조연설…로봇·자율주행 등 물리적 AI 개발 '코스모스' 공개日 ...
# 9240  ◆…미 연방준비제도(Fed)가 당분간 금리를 동결하고 올해 금리 인하를 단 한번 단...
# 9241  일본제철, 바이든 불허 불복 소송하시모토 회장 “美에 항전할 것”트럼프 “관세로 더...
# 9242  페이스북과 인스타그램 등을 운영하는 메타플랫폼의 마크 저커버그 최고경영자(CEO)가...
#
# [9243 rows x 2 columns]

# %%
df.loc[:, '뉴스제목'] = df['뉴스제목'].apply(text_clean)
df.loc[:, '본문'] = df['본문'].apply(text_clean)

# %%
df
# Out:
#                                                뉴스제목  \
# 0           FIU 은행 증권 보험 등 전 금융사와 초국경 범죄 거래 유형 분석한다
# 1            금감원 금융보안원 가입 GA에 운영실태평가 가점 보안 역량 끌어올린다
# 2                회계법인 감사보수 뚝 떨어지자 금감원 보수 경쟁보다 품질 우선
# 3                 금감원장 키움증권 찾아 모범사례 당부 발행어음 투자 주의점은
# 4                 토스뱅크 금융권 첫 신분증 진위확인 소프트웨어 부수업무 신고
# ...                                             ...
# 9238                    인도네시아 브릭스 가입 중국에 한 발 더 가까워져
# 9239  CES 2025 젠슨 황 로봇 개발 플랫폼 공개 로봇의 챗GPT 모멘트 온다 종합
# 9240                연준 확고한 동결 신호 보내 올해 금리 인하 1회 가능성
# 9241         인수 포기 못 해 vs 지금 못 팔아 US스틸 매각 놓고  갈등 확산
# 9242                        트럼프 복귀에 저커버그 페북 팩트체킹 폐지
#
#                                                      본문
# 0     이형주 자금세탁방지 유관기관협의회 개최앞으로 금융정보분석원 FIU 은 은행 저축은행...
# 1     이미지 게티이미지뱅크금융감독원이 금융보안원에 가입한 보험대리점 GA 에 대해 내부통...
# 2     감사 부문 전년대비 증가폭 둔화 비감사 부문은 확대회계법인이 외부감사를 통해 받는 ...
# 3     정부 정책 따라 발행어음 사업자 증가경쟁 심화되면 부실 우려 커질 수도 리스크 관리...
# 4     인공지능 AI 기반 신분증 진위확인 기술 제공토스뱅크가 금융권 최초로 신분증 진위확...
# ...                                                 ...
# 9238  수출시장 확대 달러 의존도 낮추는 데 도움 서방집단 합류 해석 우려중국 인도네시아 ...
# 9239  젠슨 황 8년만에 기조연설 로봇 자율주행 등 물리적 AI 개발 코스모스 공개 도요타...
# 9240  미 연방준비제도 Fed 가 당분간 금리를 동결하고 올해 금리 인하를 단 한번 단행할...
# 9241  일본제철 바이든 불허 불복 소송하시모토 회장 에 항전할 것 트럼프 관세로 더 수익 ...
# 9242  페이스북과 인스타그램 등을 운영하는 메타플랫폼의 마크 저커버그 최고경영자 CEO 가...
#
# [9243 rows x 2 columns]

# %% [markdown]
# # wordcloud화

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from wordcloud) (2.3.5)
# Requirement already satisfied: pillow in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=3 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
from wordcloud import WordCloud

# %%
text_data = df['뉴스제목'].astype(str).tolist()
text_data = df['본문'].astype(str).tolist()
full_text = " ".join(text_data)

# %%
df
# Out:
#                                                뉴스제목  \
# 0           FIU 은행 증권 보험 등 전 금융사와 초국경 범죄 거래 유형 분석한다
# 1            금감원 금융보안원 가입 GA에 운영실태평가 가점 보안 역량 끌어올린다
# 2                회계법인 감사보수 뚝 떨어지자 금감원 보수 경쟁보다 품질 우선
# 3                 금감원장 키움증권 찾아 모범사례 당부 발행어음 투자 주의점은
# 4                 토스뱅크 금융권 첫 신분증 진위확인 소프트웨어 부수업무 신고
# ...                                             ...
# 9238                    인도네시아 브릭스 가입 중국에 한 발 더 가까워져
# 9239  CES 2025 젠슨 황 로봇 개발 플랫폼 공개 로봇의 챗GPT 모멘트 온다 종합
# 9240                연준 확고한 동결 신호 보내 올해 금리 인하 1회 가능성
# 9241         인수 포기 못 해 vs 지금 못 팔아 US스틸 매각 놓고  갈등 확산
# 9242                        트럼프 복귀에 저커버그 페북 팩트체킹 폐지
#
#                                                      본문
# 0     이형주 자금세탁방지 유관기관협의회 개최앞으로 금융정보분석원 FIU 은 은행 저축은행...
# 1     이미지 게티이미지뱅크금융감독원이 금융보안원에 가입한 보험대리점 GA 에 대해 내부통...
# 2     감사 부문 전년대비 증가폭 둔화 비감사 부문은 확대회계법인이 외부감사를 통해 받는 ...
# 3     정부 정책 따라 발행어음 사업자 증가경쟁 심화되면 부실 우려 커질 수도 리스크 관리...
# 4     인공지능 AI 기반 신분증 진위확인 기술 제공토스뱅크가 금융권 최초로 신분증 진위확...
# ...                                                 ...
# 9238  수출시장 확대 달러 의존도 낮추는 데 도움 서방집단 합류 해석 우려중국 인도네시아 ...
# 9239  젠슨 황 8년만에 기조연설 로봇 자율주행 등 물리적 AI 개발 코스모스 공개 도요타...
# 9240  미 연방준비제도 Fed 가 당분간 금리를 동결하고 올해 금리 인하를 단 한번 단행할...
# 9241  일본제철 바이든 불허 불복 소송하시모토 회장 에 항전할 것 트럼프 관세로 더 수익 ...
# 9242  페이스북과 인스타그램 등을 운영하는 메타플랫폼의 마크 저커버그 최고경영자 CEO 가...
#
# [9243 rows x 2 columns]

# %%
print(type(full_text))
print(full_text[:200])
# Out:
# <class 'str'>
# 이형주 자금세탁방지 유관기관협의회 개최앞으로 금융정보분석원 FIU 은 은행 저축은행 증권 보험 등 전 금융권과 협력해 초국경 범죄 의심거래 유형을 분석하기로 했다 금융회사들이 의심거래를 보고하면 FIU가 의심거래를 분석하면 법 집행기관에서 범죄조직 적발에 활용할 계획이다 FIU는 금감원 16개 유관기관 등과 함께 초국경 범죄 관련 자금세탁방지 AML 유관기

# %%
text_data = df[['뉴스제목', '본문']].fillna('').astype(str)
full_text = (text_data['뉴스제목'] + " " + text_data['본문']).str.cat(sep=" ")

# %%
df['뉴스제목'] = df.get('뉴스제목', pd.Series(['']*len(df))).fillna('').astype(str)
df['본문'] = df.get('본문', pd.Series(['']*len(df))).fillna('').astype(str)

# 3. 두 컬럼 합치기
df['full_text'] = df['뉴스제목'] + ' ' + df['본문']

# 4. Mecab 명사 추출
from konlpy.tag import Mecab
mecab = Mecab()
df['nouns'] = df['full_text'].apply(lambda x: [w for w in mecab.nouns(x) if len(w) > 1])

# 5. 불용어 제거
stopwords = set([
    '한국핀테크지원센터', '한국핀테크산업협회', '핀테크', '채용관', '핀테크기업', '기업', '은행',
    '사람인', 'saramin', '모집', '상반기', '참여', '한국', '뱅크', '과정', '업계',
    '기준', '분기', '프로그램', '개최', '지원', '금융', '센터', '2025', '2025년',
    '금융당국', '공고','카카오','토스','기관','관련','혁신','당국','시장'])
df['nouns'] = df['nouns'].apply(lambda x: [w for w in x if w not in stopwords])

all_nouns = []
for tokens in df['nouns']:
    all_nouns.extend(tokens)
filtered = all_nouns

# 확인
print(df[['full_text','nouns']].head())
# Out:
#                                            full_text  \
# 0  FIU 은행 증권 보험 등 전 금융사와 초국경 범죄 거래 유형 분석한다 이형주 자금...
# 1  금감원 금융보안원 가입 GA에 운영실태평가 가점 보안 역량 끌어올린다 이미지 게티이...
# 2  회계법인 감사보수 뚝 떨어지자 금감원 보수 경쟁보다 품질 우선 감사 부문 전년대비 ...
# 3  금감원장 키움증권 찾아 모범사례 당부 발행어음 투자 주의점은 정부 정책 따라 발행어...
# 4  토스뱅크 금융권 첫 신분증 진위확인 소프트웨어 부수업무 신고 인공지능 AI 기반 신...
#
#                                                nouns
# 0  [증권, 보험, 국경, 범죄, 거래, 유형, 분석, 이형주, 자금, 세탁, 방지, ...
# 1  [금감원, 보안원, 가입, 운영, 실태, 평가, 보안, 역량, 이미지, 게티, 이미...
# 2  [회계, 법인, 감사, 보수, 금감원, 보수, 경쟁, 품질, 감사, 부문, 전년, ...
# 3  [금감원, 키움증권, 모범, 사례, 당부, 발행, 어음, 투자, 정부, 정책, 발행...
# 4  [신분증, 진위, 확인, 소프트웨어, 부수, 업무, 신고, 인공지능, 기반, 신분증...

# %%
from collections import Counter
word_freq = Counter(filtered)
word_freq
# Out:
# Counter({'대출': 24879,
#          '금리': 19084,
#          '보험': 18981,
#          '투자': 17145,
#          '자산': 15440,
#          '서비스': 14221,
#          '미국': 14135,
#          '코인': 12045,
#          '상품': 11618,
#          '카드': 11243,
#          '가능': 10732,
#          '스테이': 10398,
#          '결제': 10240,
#          '지난해': 9109,
#          '달러': 9039,
#          '고객': 8795,
#          '규제': 8753,
#          '거래': 8623,
#          '확대': 8360,
#          '중국': 8099,
#          '관리': 7763,
#          '디지털': 7743,
#          '국내': 7659,
#          '수익': 7641,
#          '올해': 7503,
#          '제공': 7472,
#          '증가': 7453,
#          '기술': 7291,
#          '증권': 7229,
#          '신용': 7223,
#          '자금': 7136,
#          '정부': 7131,
#          '규모': 7104,
#          '정책': 7029,
#          '필요': 6998,
#          '경우': 6974,
#          '제도': 6871,
#          '우리': 6774,
#          '최근': 6716,
#          '강화': 6692,
#          '이상': 6607,
#          '자본': 6554,
#          '하나': 6425,
#          '대비': 6218,
#          '경제': 6197,
#          '저축': 6150,
#          '페이': 6123,
#          '관계자': 6110,
#          '정보': 5975,
#          '기반': 5965,
#          '평가': 5790,
#          '이후': 5769,
#          '활용': 5700,
#          '트럼프': 5611,
#          '때문': 5601,
#          '가상': 5498,
#          '글로벌': 5455,
#          '관세': 5410,
#          '발행': 5407,
#          '성장': 5386,
#          '데이터': 5381,
#          '사업': 5347,
#          '사용': 5339,
#          '해외': 5323,
#          '상황': 5322,
#          '도입': 5274,
#          '연금': 5247,
#          '수준': 5091,
#          '소비자': 5054,
#          '계획': 5025,
#          '수수료': 5016,
#          '개인': 5010,
#          '전망': 4938,
#          '인하': 4937,
#          '구조': 4853,
#          '기자': 4849,
#          '가계': 4837,
#          '산업': 4821,
#          '투자자': 4816,
#          '시스템': 4780,
#          '예금': 4741,
#          '전략': 4695,
#          '운영': 4692,
#          '위원회': 4641,
#          '서울': 4592,
#          '대상': 4589,
#          '기존': 4580,
#          '이번': 4357,
#          '최대': 4345,
#          '주요': 4323,
#          '회사': 4270,
#          '주식': 4101,
#          '개선': 4090,
#          '안정': 4084,
#          '분석': 4080,
#          '영업': 4043,
#          '대표': 4026,
#          '출시': 4014,
#          '계좌': 3972,
#          '지급': 3954,
#          '포인트': 3899,
#          '이용': 3882,
#          '금감원': 3868,
#          '중심': 3866,
#          '적용': 3864,
#          '펀드': 3859,
#          '설명': 3819,
#          '시간': 3785,
#          '부담': 3769,
#          '대통령': 3742,
#          '거래소': 3688,
#          '보호': 3687,
#          '운용': 3674,
#          '기간': 3664,
#          '위험': 3662,
#          '발표': 3651,
#          '추가': 3647,
#          '판매': 3633,
#          '확보': 3630,
#          '추진': 3620,
#          '신한': 3565,
#          '상승': 3562,
#          '기록': 3553,
#          '발생': 3551,
#          '예정': 3547,
#          '우려': 3547,
#          '비율': 3531,
#          '문제': 3514,
#          '플랫': 3508,
#          '세계': 3507,
#          '영향': 3481,
#          '지속': 3469,
#          '비용': 3465,
#          '부동산': 3439,
#          '지역': 3427,
#          '가입': 3399,
#          '국가': 3374,
#          '개발': 3345,
#          '방식': 3337,
#          '마련': 3321,
#          '업무': 3296,
#          '인터넷': 3285,
#          '경쟁': 3277,
#          '국민': 3226,
#          '담보': 3207,
#          '대응': 3188,
#          '진행': 3138,
#          '수요': 3131,
#          '사업자': 3094,
#          '방안': 3091,
#          '채권': 3090,
#          '화폐': 3085,
#          '혜택': 3074,
#          '한도': 3069,
#          '증권사': 3058,
#          '시중': 3019,
#          '주택': 3016,
#          '전환': 3014,
#          '비중': 2970,
#          '예상': 2963,
#          '통화': 2962,
#          '개월': 2957,
#          '가치': 2956,
#          '전체': 2949,
#          '실적': 2948,
#          '지적': 2915,
#          '이익': 2905,
#          '구축': 2896,
#          '일부': 2895,
#          '전년': 2890,
#          '시작': 2880,
#          '장기': 2869,
#          '사진': 2868,
#          '유지': 2855,
#          '계약': 2852,
#          '손해': 2845,
#          '전문': 2832,
#          '조치': 2805,
#          '핵심': 2792,
#          '원화': 2791,
#          '체계': 2785,
#          '기대': 2785,
#          '공급': 2782,
#          '가격': 2768,
#          '효과': 2764,
#          '준비': 2753,
#          '보험료': 2751,
#          '모델': 2745,
#          '리스크': 2728,
#          '신규': 2728,
#          '보장': 2712,
#          '만큼': 2709,
#          '지난달': 2704,
#          '업체': 2699,
#          '포함': 2678,
#          '연체': 2674,
#          '감소': 2668,
#          '최고': 2657,
#          '확인': 2648,
#          '사회': 2631,
#          '결과': 2622,
#          '이자': 2621,
#          '비교': 2608,
#          '일본': 2606,
#          '하락': 2599,
#          '신청': 2599,
#          '단계': 2589,
#          '시행': 2573,
#          '보유': 2570,
#          '적극': 2525,
#          '감독원': 2501,
#          '잔액': 2496,
#          '퇴직': 2484,
#          '변화': 2477,
#          '가운데': 2472,
#          '평균': 2453,
#          '법인': 2433,
#          '네이버': 2433,
#          '농협': 2432,
#          '강조': 2422,
#          '해당': 2417,
#          '현지': 2396,
#          '통장': 2385,
#          '금액': 2382,
#          '인프라': 2378,
#          '블록체인': 2372,
#          '제한': 2348,
#          '논의': 2345,
#          '미래': 2342,
#          '내부': 2322,
#          '부채': 2322,
#          '사고': 2313,
#          '부과': 2312,
#          '자체': 2292,
#          '기능': 2280,
#          '검토': 2270,
#          '생산': 2258,
#          '뉴스': 2250,
#          '이유': 2245,
#          '결정': 2245,
#          '사례': 2243,
#          '외국인': 2220,
#          '중요': 2204,
#          '감독': 2200,
#          '토큰': 2185,
#          '보안': 2183,
#          '고려': 2179,
#          '분야': 2175,
#          '완화': 2168,
#          '자동차': 2164,
#          '목표': 2159,
#          '경영': 2134,
#          '조정': 2130,
#          '상장': 2130,
#          '피해': 2113,
#          '인공지능': 2095,
#          '역할': 2093,
#          '무역': 2091,
#          '통제': 2090,
#          '경기': 2082,
#          '입장': 2074,
#          '보험금': 2067,
#          '송금': 2058,
#          '생명': 2056,
#          '향후': 2052,
#          '속도': 2044,
#          '이전': 2044,
#          '케이': 2035,
#          '지방': 2023,
#          '상호': 2020,
#          '부실': 2017,
#          '점검': 2016,
#          '요구': 1993,
#          '환경': 1992,
#          '테크': 1966,
#          '절차': 1960,
#          '수단': 1960,
#          '연구': 1959,
#          '그룹': 1950,
#          '반영': 1946,
#          '심사': 1939,
#          '신뢰': 1929,
#          '지주': 1916,
#          '집중': 1914,
#          '경쟁력': 1903,
#          '확장': 1899,
#          '협력': 1897,
#          '변동': 1896,
#          '적금': 1893,
#          '오픈': 1890,
#          '현금': 1887,
#          '공개': 1877,
#          '연합뉴스': 1842,
#          '이날': 1832,
#          '연구원': 1828,
#          '유동': 1825,
#          '애플': 1811,
#          '내용': 1805,
#          '공동': 1782,
#          '순이익': 1775,
#          '상환': 1774,
#          '신탁': 1769,
#          '스타트업': 1768,
#          '신한은행': 1743,
#          '활성': 1742,
#          '반면': 1740,
#          '다양': 1731,
#          '삼성': 1713,
#          '국제': 1708,
#          '선택': 1704,
#          '국민은행': 1703,
#          '이달': 1698,
#          '수출': 1696,
#          '조사': 1695,
#          '공시': 1692,
#          '회의': 1691,
#          '민간': 1690,
#          '실제': 1677,
#          '유럽': 1673,
#          '모바일': 1666,
#          '환율': 1665,
#          '전문가': 1662,
#          '자동': 1660,
#          '일반': 1657,
#          '만기': 1648,
#          '가입자': 1640,
#          '국채': 1638,
#          '조달': 1635,
#          '본격': 1632,
#          '흐름': 1627,
#          '작년': 1626,
#          '인수': 1625,
#          '진출': 1622,
#          '책임': 1622,
#          '하반기': 1621,
#          '한국은행': 1606,
#          '세대': 1602,
#          '설계': 1591,
#          '이용자': 1578,
#          '지정': 1571,
#          '취급': 1568,
#          '시대': 1565,
#          '연계': 1564,
#          '허용': 1556,
#          '종합': 1551,
#          '소득': 1549,
#          '비디아': 1548,
#          '주담': 1531,
#          '판단': 1509,
#          '기본': 1508,
#          '교육': 1507,
#          '협회': 1502,
#          '소비': 1502,
#          '부문': 1499,
#          '반도체': 1494,
#          '방향': 1492,
#          '사기': 1492,
#          '대형': 1486,
#          '차지': 1480,
#          '손실': 1476,
#          '방침': 1474,
#          '프로젝트': 1469,
#          '주가': 1465,
#          '단기': 1461,
#          '급증': 1454,
#          '전반': 1453,
#          '규정': 1453,
#          '다음': 1452,
#          '여신': 1450,
#          '효율': 1450,
#          '지수': 1449,
#          '관심': 1442,
#          '확산': 1429,
#          '보고서': 1422,
#          '단순': 1421,
#          '전자': 1421,
#          '조건': 1418,
#          '인상': 1416,
#          '주목': 1414,
#          '동시': 1406,
#          '기회': 1397,
#          '매출': 1390,
#          '서민': 1384,
#          '여부': 1369,
#          '검사': 1368,
#          '처리': 1368,
#          '집계': 1362,
#          '동기': 1361,
#          '증시': 1352,
#          '벤처': 1348,
#          '자료': 1347,
#          '위기': 1343,
#          '홍콩': 1340,
#          '중소기업': 1335,
#          '중단': 1331,
#          '협상': 1328,
#          '설립': 1326,
#          '비트코인': 1317,
#          '연결': 1316,
#          '유통': 1316,
#          '상태': 1315,
#          '사람': 1315,
#          '연간': 1312,
#          '주주': 1312,
#          '매각': 1306,
#          '제시': 1300,
#          '통신': 1299,
#          '나라': 1299,
#          '노력': 1298,
#          '온라인': 1295,
#          '안전': 1292,
#          '모습': 1291,
#          '원장': 1287,
#          '대부분': 1285,
#          '영국': 1283,
#          '경험': 1282,
#          '보험업': 1281,
#          '조직': 1275,
#          '출범': 1272,
#          '대신': 1270,
#          '행사': 1270,
#          '최초': 1269,
#          '통합': 1268,
#          '점포': 1262,
#          '인증': 1261,
#          '악화': 1260,
#          '인식': 1258,
#          '정도': 1258,
#          '동안': 1257,
#          '주도': 1254,
#          '고정': 1253,
#          '실질': 1252,
#          '현대': 1251,
#          '성과': 1249,
#          '제기': 1244,
#          '지표': 1244,
#          '현장': 1242,
#          '자리': 1241,
#          '생활': 1241,
#          '당시': 1240,
#          '도널드': 1240,
#          '제재': 1239,
#          '재무': 1237,
#          '과제': 1235,
#          '중앙은행': 1234,
#          '발전': 1233,
#          '구성': 1231,
#          '개정': 1228,
#          '중앙': 1226,
#          '성공': 1207,
#          '지분': 1206,
#          '제휴': 1206,
#          '구체': 1205,
#          '한편': 1202,
#          '법안': 1196,
#          '의미': 1191,
#          '연동': 1190,
#          '요인': 1188,
#          '처음': 1186,
#          '취약': 1184,
#          '수도': 1184,
#          '실물': 1182,
#          '일정': 1179,
#          '의견': 1179,
#          '배당': 1175,
#          '시점': 1170,
#          '인도': 1170,
#          '회계': 1168,
#          '현실': 1168,
#          '상대': 1167,
#          '생성': 1166,
#          '금지': 1164,
#          '보증': 1161,
#          '부족': 1157,
#          '축소': 1151,
#          '화재': 1149,
#          '내년': 1147,
#          '누적': 1146,
#          '사전': 1142,
#          '현재': 1141,
#          '사태': 1141,
#          '방지': 1136,
#          '목적': 1134,
#          '관계': 1130,
#          '물가': 1125,
#          '전쟁': 1123,
#          '외부': 1121,
#          '외환': 1121,
#          '제외': 1120,
#          '역량': 1116,
#          '발급': 1112,
#          '등록': 1110,
#          '개편': 1110,
#          '이미지': 1109,
#          '행정부': 1102,
#          '직원': 1100,
#          '차원': 1096,
#          '사항': 1082,
#          '교수': 1082,
#          '채널': 1078,
#          '등급': 1076,
#          '협업': 1076,
#          '제출': 1071,
#          '범위': 1070,
#          '공매도': 1070,
#          '위원': 1068,
#          '영역': 1066,
#          '연준': 1063,
#          '상담': 1060,
#          '생태': 1058,
#          '자율': 1054,
#          '고도': 1053,
#          '특정': 1052,
#          '뉴시스': 1051,
#          '맞춤': 1049,
#          '자기': 1048,
#          '기조': 1046,
#          '요건': 1045,
#          '데일리': 1044,
#          '주문': 1043,
#          '주장': 1043,
#          '사실': 1041,
#          '뱅킹': 1037,
#          '수신': 1034,
#          '암호': 1033,
#          '회복': 1032,
#          '상공': 1029,
#          '급여': 1029,
#          '인력': 1025,
#          '행위': 1022,
#          '적립': 1020,
#          '체결': 1019,
#          '회장': 1019,
#          '전용': 1014,
#          '피싱': 1013,
#          '보상': 1011,
#          '과거': 1011,
#          '의원': 1009,
#          '최소': 1009,
#          '불법': 1008,
#          '돌파': 1007,
#          '위원장': 1005,
#          '포트폴리오': 1002,
#          '승인': 1001,
#          '여기': 1001,
#          '한계': 1001,
#          '재정': 998,
#          '감사': 994,
#          '차이': 992,
#          '의무': 987,
#          '제고': 982,
#          '부분': 981,
#          '모임': 975,
#          '지점': 971,
#          '활동': 969,
#          '고령': 969,
#          '상자': 967,
#          '간담회': 961,
#          '별도': 961,
#          '사이': 960,
#          '초기': 956,
#          '측면': 956,
#          '전통': 954,
#          '청구': 951,
#          '개설': 951,
#          '형태': 949,
#          '차주': 946,
#          '편의': 946,
#          '국회': 945,
#          '트래블': 945,
#          '한은': 944,
#          '체크카드': 940,
#          '예방': 938,
#          '유치': 937,
#          '구글': 936,
#          '매매': 934,
#          '현상': 933,
#          '유출': 930,
#          '담대': 929,
#          '제품': 929,
#          '대체': 922,
#          '건강': 920,
#          '오프라인': 919,
#          '적자': 918,
#          '차단': 917,
#          '실행': 917,
#          '상향': 916,
#          '보이스': 915,
#          '선정': 914,
#          '정기': 913,
#          '연속': 904,
#          '실시간': 904,
#          '정리': 903,
#          '대책': 903,
#          '특화': 902,
#          '능력': 899,
#          '유도': 899,
#          '전세': 898,
#          '가맹점': 898,
#          '해결': 894,
#          '접근': 893,
#          '유입': 893,
#          '설정': 892,
#          '머니': 890,
#          '여력': 887,
#          '가량': 885,
#          '역대': 884,
#          '진입': 883,
#          '위안': 883,
#          '연방': 883,
#          '수행': 881,
#          '접근성': 881,
#          '지금': 880,
#          '공인': 878,
#          '바탕': 878,
#          '점유': 876,
#          '재개': 872,
#          '정기예금': 871,
#          '플랫폼': 871,
#          '투명': 870,
#          '계층': 870,
#          '광고': 870,
#          '정치': 869,
#          '과세': 868,
#          '환전': 866,
#          '결합': 865,
#          '필수': 864,
#          '정산': 862,
#          '추세': 860,
#          '분리': 860,
#          '그래픽': 857,
#          '생각': 856,
#          '신고': 855,
#          '의료': 853,
#          '클라우드': 853,
#          '현황': 850,
#          '추천': 850,
#          '본인': 850,
#          '신설': 850,
#          '공유': 849,
#          '구매': 844,
#          '자회사': 842,
#          '위반': 840,
#          '전국': 838,
#          '파이낸셜': 836,
#          '이해': 835,
#          '솔루션': 835,
#          '조성': 834,
#          '시크': 834,
#          '납입': 832,
#          '이하': 830,
#          '가지': 830,
#          '과징금': 829,
#          '할인': 827,
#          '방법': 826,
#          '외화': 825,
#          '대안': 824,
#          '청년': 822,
#          '종목': 822,
#          '절반': 820,
#          '정상': 820,
#          '첨단': 816,
#          '안내': 815,
#          '마켓': 813,
#          '시기': 812,
#          '제보': 811,
#          '건수': 807,
#          '전월': 807,
#          '예측': 806,
#          '설계사': 805,
#          '합의': 804,
#          '소상': 803,
#          '방문': 803,
#          '공공': 803,
#          '공격': 802,
#          '사망': 802,
#          '확정': 801,
#          '포용': 795,
#          '분위기': 794,
#          '시니어': 792,
#          '매입': 790,
#          '초과': 787,
#          '정비': 787,
#          '둔화': 786,
#          '넥스트': 786,
#          '실시': 785,
#          '작용': 785,
#          '원칙': 780,
#          '결국': 779,
#          '중소': 779,
#          '달성': 777,
#          '차례': 777,
#          '차별': 776,
#          '진단': 771,
#          '압박': 771,
#          '변경': 770,
#          '침체': 769,
#          '목소리': 766,
#          '하루': 765,
#          '기여': 764,
#          '증가세': 762,
#          '브랜드': 762,
#          '기금': 761,
#          '상당': 754,
#          '연장': 753,
#          '홈페이지': 752,
#          '수입': 752,
#          '전산': 751,
#          '위협': 751,
#          '원금': 749,
#          '협약': 747,
#          '사모': 747,
#          '개혁': 743,
#          '마케팅': 742,
#          '경고': 741,
#          '조각': 741,
#          '표준': 740,
#          '긍정': 740,
#          '요청': 738,
#          '해소': 738,
#          '장관': 738,
#          '해석': 735,
#          '지출': 734,
#          '연말': 732,
#          '흑자': 732,
#          '파악': 731,
#          '검증': 725,
#          '이사': 724,
#          '창출': 724,
#          '검색': 723,
#          '통과': 719,
#          '편입': 717,
#          '기획': 717,
#          '예고': 717,
#          '보완': 716,
#          '콘텐츠': 716,
#          '최종': 715,
#          '중개': 715,
#          '테스트': 715,
#          '문화': 712,
#          '컨소시엄': 711,
#          '지배': 709,
#          '고용': 706,
#          '육성': 706,
#          '밸류': 705,
#          '자유': 703,
#          '모니터링': 703,
#          '범죄': 699,
#          '선제': 698,
#          '자신': 697,
#          '아시아': 695,
#          '풀이': 695,
#          '고민': 693,
#          '공식': 692,
#          '동결': 692,
#          '협의': 691,
#          '인플레이션': 690,
#          '지연': 689,
#          '언급': 688,
#          '소액': 688,
#          '네트워크': 687,
#          '점수': 686,
#          '담당': 686,
#          '매수': 684,
#          '베트남': 683,
#          '세금': 683,
#          '메리': 680,
#          '해킹': 675,
#          '가이드라인': 674,
#          '어려움': 674,
#          '보도': 674,
#          '부진': 672,
#          '보수': 671,
#          '비판': 671,
#          '인구': 669,
#          '롯데': 668,
#          '충당': 668,
#          '작업': 668,
#          '도움': 665,
#          '항목': 664,
#          '기사': 663,
#          '총량': 663,
#          '등장': 663,
#          '취지': 659,
#          '시도': 659,
#          '당기': 659,
#          '대금': 659,
#          '인기': 659,
#          '개정안': 658,
#          '자사': 654,
#          '창구': 654,
#          '스트레스': 652,
#          '절감': 651,
#          '유니콘': 651,
#          '조회': 650,
#          '존재': 650,
#          '집행': 649,
#          '배경': 649,
#          '책무': 649,
#          '단위': 648,
#          '접수': 644,
#          '비트': 644,
#          '원리금': 641,
#          '가속': 639,
#          '급등': 639,
#          '싱가포르': 639,
#          '한화': 638,
#          '수령': 638,
#          '노후': 636,
#          '레이드': 636,
#          '부정': 635,
#          '계열사': 635,
#          '움직임': 635,
#          '충족': 635,
#          '총재': 631,
#          '심화': 629,
#          '부산': 629,
#          '사상': 629,
#          '마을금고': 626,
#          '격차': 625,
#          '관측': 625,
#          '각종': 623,
#          '주체': 623,
#          '통상': 622,
#          '유리': 619,
#          '우대금리': 618,
#          '설치': 617,
#          '완료': 617,
#          '여행': 617,
#          '로이터': 617,
#          '법정': 613,
#          '재산': 613,
#          '형성': 612,
#          '일상': 611,
#          '지갑': 610,
#          '환급': 609,
#          '패권': 607,
#          '유로': 605,
#          '비즈니스': 603,
#          '제안': 602,
#          '참석': 601,
#          '단말기': 600,
#          '고금리': 599,
#          '불안': 599,
#          '균형': 599,
#          '연내': 598,
#          '입법': 596,
#          '특성': 595,
#          '요양': 595,
#          '라이프': 593,
#          '그동안': 591,
#          '공정': 589,
#          '분산': 589,
#          '독일': 589,
#          '얼굴': 588,
#          '우대': 588,
#          '메타': 585,
#          '무엇': 585,
#          '상생': 584,
#          '개별': 584,
#          '알고리즘': 584,
#          '가산': 584,
#          '이동': 583,
#          '그간': 581,
#          '추정': 578,
#          '스타': 576,
#          '거래량': 576,
#          '동일': 575,
#          '임원': 575,
#          '예대': 574,
#          '행정': 573,
#          '민주당': 572,
#          '유예': 572,
#          '위축': 571,
#          '시각': 571,
#          '쿠폰': 570,
#          '회수': 570,
#          '전달': 568,
#          '예비': 567,
#          '산정': 567,
#          '환원': 567,
#          '세탁': 566,
#          '연구소': 566,
#          '형사': 565,
#          '편리': 565,
#          '분류': 565,
#          '전면': 564,
#          '장치': 563,
#          '희토류': 562,
#          '연합회': 561,
#          '경영자': 560,
#          '주기': 558,
#          '뉴욕': 558,
#          '무료': 557,
#          '파트너': 557,
#          '감안': 557,
#          '선물': 557,
#          '창업': 556,
#          '투입': 555,
#          '반복': 554,
#          '오전': 553,
#          '외국': 553,
#          '요소': 552,
#          '금융업': 550,
#          '코드': 549,
#          '비상': 548,
#          '성장세': 547,
#          '준비금': 546,
#          '오후': 545,
#          '의사': 545,
#          '배상': 545,
#          '대환': 543,
#          '촉진': 543,
#          '이재명': 542,
#          '플러스': 541,
#          '맹점': 541,
#          '특징': 541,
#          '반대': 541,
#          '대부': 540,
#          '여의도': 538,
#          '부당': 537,
#          '아이': 536,
#          '매도': 536,
#          '확충': 536,
#          '캐나다': 536,
#          '예산': 535,
#          '납부': 534,
#          '제조': 533,
#          '합리': 532,
#          '부여': 530,
#          '일각': 530,
#          '합병': 529,
#          '태국': 529,
#          '약화': 528,
#          '월렛': 528,
#          '스마트폰': 527,
#          '성능': 527,
#          '원인': 526,
#          '통계': 524,
#          '심리': 524,
#          '신용자': 523,
#          '업종': 521,
#          '실험': 521,
#          '인정': 520,
#          '다수': 519,
#          '예금자': 517,
#          '근거': 517,
#          '충격': 516,
#          '장점': 515,
#          '최저': 515,
#          '신속': 515,
#          '미만': 514,
#          '블룸버그': 514,
#          '모색': 514,
#          '자녀': 512,
#          '손익': 511,
#          '종신': 511,
#          '자국': 511,
#          '장사': 510,
#          '중도': 508,
#          '연합': 507,
#          '각국': 505,
#          '논란': 504,
#          '문턱': 503,
#          '기초': 503,
#          '제약': 502,
#          '가중': 501,
#          '체제': 501,
#          '에너지': 501,
#          '특약': 500,
#          '치열': 499,
#          '현행': 499,
#          '시설': 498,
#          '법률': 498,
#          '탐지': 496,
#          '마진': 496,
#          '인도네시아': 496,
#          '실현': 494,
#          '질문': 493,
#          '안심': 493,
#          '선임': 491,
#          '자산관리': 491,
#          '이벤트': 490,
#          '이행': 489,
#          '도전': 489,
#          '과도': 488,
#          '과학': 488,
#          '방어': 487,
#          '게임': 487,
#          '데일리안': 486,
#          '질서': 486,
#          '옵션': 486,
#          '공제': 484,
#          '기대감': 484,
#          '코스피': 483,
#          '선호': 482,
#          '전화': 481,
#          '아파트': 480,
#          '재편': 480,
#          '발언': 479,
#          ...})

# %%
wc = WordCloud(
        font_path='NanumGothic.ttf',
        background_color='white',
        width=800,
        height=400).generate_from_frequencies(word_freq)
plt.figure(figsize=(10,5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title("핀테크 뉴스 주제")
plt.show()

# %% [markdown]
# # LDA 모델링

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from gensim) (2.3.5)
# Requirement already satisfied: scipy>=1.7.0 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages (from smart_open>=1.8.1->gensim) (2.0.1)

# %%
from gensim.models import CoherenceModel
from gensim import corpora
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# mecab 으로 명사만 추출해서 길이가 2 이상인 것만 모아서 리스트로 만드는 함수
def tokenize_texts(text_data):
    return [[word for word in mecab.nouns(doc) if len(word) > 1] for doc in text_data]

# %%
result = []
for doc in text_data:
    for word in mecab.nouns(doc):
        if len(word) > 1:
            result.append(word)

# %%
def find_optimal_topics(text_data, start=2, end=8):
    # text_data는 문자열 리스트
    tokenized_texts = tokenize_texts(text_data)
    if not tokenized_texts:
        return start
    # gensim으로 BoW(숫자로 인코딩 된 단어 모음)
    dictionary = corpora.Dictionary(tokenized_texts)
    vectorizer = CountVectorizer(tokenizer=lambda x: x, lowercase=False)
    
    try:
        doc_term_matrix = vectorizer.fit_transform(tokenized_texts)
    except:
        print("벡터화중 오류발생, 기본 토픽 수 2개 반환")
        return start
    
    best_score = -1
    best_n = start
    
    # LDA 분석
    for n_topics in range(start, end+1):
        lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
        lda_model.fit(doc_term_matrix)
        
        feature_names = vectorizer.get_feature_names_out()
        # 상위 10개의 단어를 순서대로 추출
        topics = [[feature_names[i] for i in topic.argsort()[:-11:-1]] for topic in lda_model.components_]
        
        # 응집도 계산
        cm = CoherenceModel(topics=topics, texts=tokenized_texts, dictionary=dictionary, coherence="c_v")
        score = cm.get_coherence()
        print(f"토픽수: {n_topics}, Coherence Score: {score:.4f}")
        
        if score > best_score:
            best_score = score
            best_n = n_topics
    
    print(f"최적 토픽수: {best_n} (Score: {best_score:.4f})")
    return best_n

# %%
import pandas as pd
from konlpy.tag import Mecab
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from gensim.corpora import Dictionary
from gensim.models import CoherenceModel

# %%
# --- 1. 불용어 정의 ---
stopwords = set([
    '한국핀테크지원센터', '한국핀테크산업협회', '핀테크', '채용관', '핀테크기업', '기업', '은행',
    '사람인', 'saramin', '모집', '상반기', '참여', '한국', '뱅크', '과정', '업계',
    '기준', '분기', '프로그램', '개최', '지원', '금융', '센터', '2025', '2025년',
    '금융당국', '공고','카카오','토스','기관','관련','혁신','당국','시장'
])

# --- 2. full_text 만들기 ---
df['뉴스제목'] = df.get('뉴스제목', pd.Series(['']*len(df))).fillna('').astype(str)
df['본문'] = df.get('본문', pd.Series(['']*len(df))).fillna('').astype(str)
df['full_text'] = df['뉴스제목'] + ' ' + df['본문']

# --- 3. Mecab 토큰화 ---
mecab = Mecab()
def tokenize_texts(texts):
    tokenized = []
    for doc in texts:
        if not isinstance(doc, str):
            continue
        nouns = [w for w in mecab.nouns(doc) if len(w) > 1 and w not in stopwords]
        tokenized.append(nouns)
    return tokenized

texts = df['full_text'].tolist()
tokenized_texts = tokenize_texts(texts)

# --- 4. 최적 토픽 수 찾기 ---
def find_optimal_topics(tokenized_texts, start=2, end=5):
    if not tokenized_texts:
        return start

    dictionary = Dictionary(tokenized_texts)
    vectorizer = CountVectorizer(tokenizer=lambda x: x, lowercase=False)
    try:
        doc_term_matrix = vectorizer.fit_transform(tokenized_texts)
    except:
        return start

    best_score = -1
    best_n = start
    for n_topics in range(start, end+1):
        lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
        lda_model.fit(doc_term_matrix)

        feature_names = vectorizer.get_feature_names_out()
        topics = [[feature_names[i] for i in topic.argsort()[:-11:-1]] for topic in lda_model.components_]

        cm = CoherenceModel(topics=topics, texts=tokenized_texts, dictionary=dictionary, coherence="c_v")
        score = cm.get_coherence()
        if score > best_score:
            best_score = score
            best_n = n_topics

    return best_n

best_k = find_optimal_topics(tokenized_texts, start=2, end=5)

# --- 5. LDA 모델링 ---
vectorizer = CountVectorizer(max_df=0.9, min_df=10, stop_words=list(stopwords))
review_vec = vectorizer.fit_transform([' '.join(doc) for doc in tokenized_texts])

if review_vec.shape[1] == 0:
    print("분석할 단어가 부족합니다.")
else:
    lda = LatentDirichletAllocation(n_components=best_k, learning_method='online', random_state=42)
    lda.fit(review_vec)

    words = vectorizer.get_feature_names_out()
    print(f"\n뉴스 기사 {len(texts)}건 / 토픽 {best_k}개 - 상위 단어")
    print("=" * 100)
    for i, topic in enumerate(lda.components_):
        top = [words[idx] for idx in topic.argsort()[-10:]]
        print(f"토픽 #{i}: {top}")
# Out:
# /home/user/miniforge3/envs/fintech2/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 뉴스 기사 9243건 / 토픽 5개 - 상위 단어
# ====================================================================================================
# 토픽 #0: ['투자', '대통령', '산업', '데이터', '경제', '관세', '기술', '트럼프', '중국', '미국']
# 토픽 #1: ['이용', '신용', '대출', '상품', '제공', '페이', '결제', '고객', '카드', '서비스']
# 토픽 #2: ['펀드', '거래', '투자자', '자산', '제도', '금감원', '연금', '자본', '증권', '투자']
# 토픽 #3: ['화폐', '발행', '결제', '거래', '디지털', '달러', '가상', '스테이', '자산', '코인']
# 토픽 #4: ['대비', '상품', '가계', '인하', '지난해', '저축', '증가', '보험', '금리', '대출']
