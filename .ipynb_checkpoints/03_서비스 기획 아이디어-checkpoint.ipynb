# %% [markdown]
# # 2025년 핀테크 주요뉴스 기반 서비스 기획 아이디어
#
# ## 1. Executive Summary
#
# 본 제안서는 핀테크 지원센터의 뉴스 데이터를 분석하여 도출된 **'대출/금리' 및 '규제/제도'** 의 두 가지 핵심 트렌드를 기반으로 합니다. 금융과 IT 기술의 융합을 통해 발생하는 규제 리스크를 최소화하고, 사용자의 부동산 대출 실행 불안정성을 해소하는 것이 목표입니다.
#
# 제안 서비스 **「주택담보대출 길잡이」** 는 레그테크(RegTech) 기술을 활용하여 복잡하고 변동성이 큰 부동산 대출 규제를 실시간으로 자동 분석하고, 잔금일(미래 시점) 기준의 정확한 대출 한도 예측 및 규제 준수(Compliance)를 지원하는 혁신적인 금융 솔루션입니다. 이는 데이터 분석 기반의 기획 역량과 실무 지식을 강조합니다.
#
# ## 2. 분석 개요 (Background)
#
# * 데이터 수집 기간 : 2025.01.08 ~ 2025.11.25
# * 출처 : 핀테크 지원센터 > 핀테크 주요뉴스
# * 총 뉴스 수 : 9243건
# * 분석 기법 : 텍스트 전처리, Wordcloud, LDA Topic Modeling
#
# ## 3. 핵심 분석 결과 (Insights)
#
# 핀테크 뉴스 텍스트 분석 결과, 2025년 초 핀테크 업계에서 가장 중요하게 다뤄진 주제는 다음과 같았습니다.
# ![image.png](attachment:image.png)
#
# 주요 키워드 (가장 많이 언급된 주제)
# * 토픽 #0: ['투자', '대통령', '산업', '데이터', '경제', '관세', '기술', '트럼프', '중국', '미국']
# * 토픽 #1: ['이용', '신용', '대출', '상품', '제공', '페이', '결제', '고객', '카드', '서비스']
# * 토픽 #2: ['펀드', '거래', '투자자', '자산', '제도', '금감원', '연금', '자본', '증권', '투자']
# * 토픽 #3: ['화폐', '발행', '결제', '거래', '디지털', '달러', '가상', '스테이', '자산', '코인']
# * 토픽 #4: ['대비', '상품', '가계', '인하', '지난해', '저축', '증가', '보험', '금리', '대출']
#
# → 결론: 2025년 핀테크 업계는 금리/대출 리스크에 대한 시장의 높은 관심과 더불어, 새로운 규제 환경(제도) 속에서 **기술(디지털, 데이터)** 을 활용하여 문제를 해결하려는 움직임이 가장 중요한 이슈
#
# ## 4. 문제 정의 (Problem Statement)
#
# * 정보 비대칭 및 리스크 전가: 규제 당국이 발표하는 복잡한 법령 및 유권해석을 일반 소비자는 물론, 은행 담당자도 즉시 반영하기 어려워 오류 발생 리스크가 높음.
#
# * 잔금일 예측 불가 문제: 사용자가 부동산 계약을 체결한 후 잔금일(대출 실행일)까지 규제가 변경되거나 서류 미비가 발생하여 최종 대출 한도가 달라지거나 거절되는 치명적인 리스크에 노출됨.
#
# * 비교의 한계: 현재의 대출 비교 서비스는 '현재 시점' 금리 비교에만 집중하며, '미래 잔금일' 기준의 정확한 규제 적합성 및 최종 한도를 예측해주지 못함.
#
# ## 5. 서비스 기획 아이디어 (Solution)
#
# 💡 아이디어: 주택담보대출 길잡이 (규제 자동 분석 대출 내비게이터)
#
# 의미: 뉴스의 "대출/금리" 트렌드와 "규제/제도" 트렌드, 그리고 "기술(데이터)" 트렌드를 모두 반영한 솔루션.
#
# * 핵심 기능 <br>
# 실시간 규제 패치 및 한도 분석기 (RegTech Engine)를 통해 금융 당국의 발표문, 법령 개정안을 AI가 자동 분석하고, 고객의 잔금일 기준으로 가장 엄격하고 최신화된 규제(LTV/DSR 등)를 적용하여 대출 한도 예측.
#
# * 리스크 관리 <br>
# 잔금일까지의 정책 변동, 금리 변동, 서류 미비 등 3가지 핵심 리스크를 예측하여 대시보드로 시각화하고 사전에 경고 알림 발송. (추가 기능: 대출금 상환 보장 보험 추천 등 리스크 대비 상품 연계)
#
# * 규제 준수 지원 <br>
# 고객이 업로드하는 대출 서류(계약서, 등기부 등 본)를 OCR/NLP로 분석하여, 현행 법규에 완벽하게 부합하는지 자동 검증 (Compliance Alert).
#
# ## 6. 기대 효과 (Impact)
#
# * 금융 사용자: 대출 실행 과정에서의 **규제 리스크 및 불안정성(Pain Point)** 을 해소하고, 사전에 정확한 금융 계획을 수립할 수 있게 하여 의사결정의 질을 높임.
#
# * 금융사/대출 담당자: 서류 검증 자동화(Compliance Alert)를 통해 수작업 오류를 줄이고, 심사 효율성을 높여 심사 비용을 절감하고 리스크를 낮춤.
#
# * 핀테크 업계: 법 전공 지식과 레그테크 기술을 융합하여, 단순 비교를 넘어선 규제 기반 예측 서비스라는 새로운 혁신 분야를 창출.
